# %% [markdown]
# # Программирование для всех <br>(основы работы с Python)
# ## Практикум 3.1: кортежи и работа с вложенными структурами
#
# *Алла Тамбовцева, НИУ ВШЭ*

# %% [markdown]
# ### Задача 1. Умный (не очень) будильник
#
# Напишите программу, которая запрашивает с клавиатуры слово и целое число через пробел и выводит на экран это слово, написанное большими буквами с восклицательным знаком на конце, повторенное указанное число раз (каждый раз – с новой строки). Однако, если указанное число больше 10, слово повторяется только 10 раз, а далее выводится сообщение `Будильник устал!`.
#
# **Примеры работы программы**
#
# Ввод:
#
#     Белоснежка 7
#
# Вывод:
#
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#     БЕЛОСНЕЖКА!
#
# Ввод:
#
#     утро 20
#
# Вывод:
#
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     УТРО!
#     Будильник устал!

# %%
word, count = input().split()

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Напишите программу, которая фильтрует героев на основе их места проживания:
#
# * В переменную `heroes` считывается список, где хранятся имена героев через запятую без пробела (строки).
# * В переменную `places` считывается список, где хранятся места проживания героев через запятую без пробела (строки). Каждый год соответствует студенту из списка `heroes`.
# * Гарантируется, что будет введена информация минимум для одного героя.
# * В переменную `place` считывается строка — место проживания, который нас интересует.
# * Программа выводит имена героев, которые проживают в месте, указанном в `place`, каждое на новой строке.
# * Если таких героев нет, то программа ничего не выводит.
#
# **Примеры работы программы**
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Мама
#     Лес, Москва, Париж, Москва
#     Москва
#
# Результат:
#
#     Красная Шапочка
#     Мама
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Айболит
#     Лес, Москва, Париж, Лес
#     Лес
#
# Результат:
#
#     Волк
#     Айболит
#
# Ввод:
#
#     Волк, Красная Шапочка, Бабушка, Айболит
#     Лес, Москва, Париж, Лес
#     Лондон
#
# Результат:
#
#     [ничего не выводится]

# %% [markdown]
# ### Задача 3
#
# В списке `data` хранятся данные по участникам медицинского исследования – id участника, вес на начало диеты, вес на конец диеты.
#
# a. Создайте список `loss`, содержащий информацию по тем же участникам в виде пар *id – количество сброшенных килограммов*. Если человек набрал вес в ходе диеты, то количество сброшенных килограммов будет отрицательным, это нормально.
#
# b. Используя только исходный список `data`, сохраните в список `success` с id тех, участников, чей вес после диеты оказался ниже, чем до.
#
# c. Используя только исходный список `data`, сохраните в список `success_ind` индексы участников, чей вес после диеты оказался ниже, чем до (т.е. индексы соотвествующих элементов в списке).

# %%
data = [("id56", 78, 75), 
        ("id23", 85, 85), 
        ("id12", 90, 84), 
        ("id10", 77, 79), 
        ("id99", 86, 84),
        ("id77", 72, 72),
        ("id43", 92, 86), 
        ("id48", 98, 94),
        ("id90", 89, 87),
        ("id13", 76, 71)]

### YOUR CODE HERE ###
